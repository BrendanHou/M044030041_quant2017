# %% [markdown]
# # Q1. 畫出 diamond shape

# %%
def pyramid(n):
    for i in range(n):
        print(" "*(n-i) + "*"*(2*i+1))
def reverse_pyramid(n):
    for i in range(n, -1, -1):
        print(" "*(n-i) + "*"*(2*i+1))

# %%
pyramid(5)
reverse_pyramid(5)
# Out:
#      *
#     ***
#    *****
#   *******
#  *********
# ***********
#  *********
#   *******
#    *****
#     ***
#      *

# %% [markdown]
# # Q2. 刪除重複性的資料。

# %%
import pandas as pd

# %%
# 取得公司資料
def get_companies(ex = "NASDAQ"):
    template = "http://www.nasdaq.com/screening/companies-by-industry.aspx?exchange={}&render=download"
    url = template.format(ex)
    return pd.read_csv(url)

# %%
df = get_companies()

# %%
df.head()
# Out:
#   Symbol                                    Name LastSale     MarketCap  \
# 0    PIH  1347 Property Insurance Holdings, Inc.      7.2  4.309032e+07
# 1   TURN                180 Degree Capital Corp.   1.9813  6.166115e+07
# 2   FLWS                 1-800 FLOWERS.COM, Inc.    10.85  7.011754e+08
# 3   FCCY           1st Constitution Bancorp (NJ)     18.3  1.477387e+08
# 4   SRCE                  1st Source Corporation    50.09  1.299141e+09
#
#   ADR TSO IPOyear             Sector                    Industry  \
# 0     n/a    2014            Finance  Property-Casualty Insurers
# 1     n/a     n/a            Finance  Finance/Investors Services
# 2     n/a    1999  Consumer Services      Other Specialty Stores
# 3     n/a     n/a            Finance        Savings Institutions
# 4     n/a     n/a            Finance                 Major Banks
#
#                        Summary Quote  Unnamed: 9
# 0   http://www.nasdaq.com/symbol/pih         NaN
# ...

# %%
symbols_01 = df[(df['MarketCap'] > 3e8) & (df['MarketCap'] < 4e8)]['Symbol'].tolist()

# %%
df['LastSale'] = df['LastSale'].str.replace('n/a', '0.0').astype(float)

# %%
symbols_02 = df[(df['LastSale'] > 3) & (df['LastSale'] < 5)]['Symbol'].tolist()

# %%
with open('symbols01.txt', 'w') as f:
    for symbol in symbols_01:
        f.write(symbol.strip().upper() + '\n')

# %%
with open('symbols02.txt', 'w') as f:
    for symbol in symbols_02:
        f.write(symbol.strip().upper() + '\n')

# %%
f = open('symbols01.txt')
code_01 = f.read()
code_01 = code_01.split()
print(code_01)
f.close()
# Out:
# ['AVHI', 'ABLX', 'AXAS', 'ARAY', 'ACET', 'ACHN', 'ADUS', 'AGEN', 'AGFS', 'AMOT', 'ATAX', 'AMNB', 'AMSWA', 'CRMT', 'ATRS', 'ARGX', 'ARTNA', 'ASNA', 'AVDL', 'AVEO', 'AHPA', 'AXTI', 'BWINA', 'BWINB', 'BAND', 'BSET', 'BSF', 'BBGI', 'BELFB', 'BIOS', 'BSTC', 'BOMN', 'CDZI', 'CALA', 'CATC', 'CCRC', 'CDXC', 'CHSCO', 'CTRN', 'CZNC', 'CLNE', 'CSBK', 'CDXS', 'CVGI', 'CRAI', 'BREW', 'CBAY', 'DJCO', 'DFRG', 'BOOM', 'EGLE', 'EHTH', 'LOCO', 'ESND', 'FMAO', 'FFKT', 'FDUS', 'FNLC', 'INBK', 'FVC', 'QABA', 'CIBR', 'RDVY', 'FLXS', 'FOGO', 'FOSL', 'FNKO', 'GERN', 'GILT', 'GAIN', 'GLDD', 'GNTY', 'HLIT', 'HCOM', 'HAYN', 'HIBB', 'HBCP', 'HCM', 'IDRA', 'IESC', 'ITIC', 'RING', 'TUR', 'WOOD', 'KNDI', 'LCA', 'LNDC', 'LMNR', 'MCBC', 'MGIC', 'MNKD', 'MRNS', 'MPAC', 'MLNT', 'MOBL', 'MBIO', 'NH', 'NATH', 'NKSH', 'NLNK', 'NEWT', 'NODK', 'NVEC', 'OBSV', 'OLBK', 'OSBC', 'OXFD', 'PACB', 'PBNC', 'PCSB', 'WRLS', 'PFIS', 'PERY', 'POPE', 'PBPB', 'POWL', 'PFM', 'KBWD', 'KBWY', 'PLPC', 'PRMW', 'PSC', 'PTGX', 'PLSE', 'QTRX', 
# ...

# %%
f = open('symbols02.txt')
code_02 = f.read()
code_02 = code_02.split()
print(code_02)
f.close()
# Out:
# ['ACTG', 'ARAY', 'ADMP', 'ADXS', 'ADVM', 'AGLE', 'AGEN', 'AGRX', 'AKTX', 'ALJJ', 'AMRN', 'AMDA', 'AMSC', 'ASRV', 'AMRS', 'AVXL', 'APEN', 'AGTC', 'APVO', 'AQB', 'ABUS', 'FUV', 'ARTX', 'ARWR', 'ASTC', 'AAME', 'ATOM', 'LIFE', 'AUPH', 'ATXI', 'AWRE', 'AXSM', 'BLDP', 'BEBE', 'BCRX', 'BMRA', 'BBOX', 'BKEP', 'BCLI', 'BVSN', 'BSQR', 'CLBS', 'CPLP', 'CARV', 'CASC', 'CPRX', 'CATS', 'CECE', 'CETV', 'CERS', 'CSBR', 'CHFS', 'CMRX', 'CADC', 'CALI', 'CAAS', 'CCCR', 'CREG', 'CXDC', 'CTXR', 'CLIR', 'CBLI', 'CODA', 'CODX', 'JVA', 'COGT', 'JCS', 'CNAT', 'CPSS', 'CPAH', 'CYRXW', 'CTIB', 'CYAN', 'DTEA', 'DWSN', 'TACOW', 'DHXM', 'LYL', 'DRYS', 'EGLE', 'ESDI', 'EGAN', 'ELSE', 'ELTK', 'EMMS', 'ECYT', 'NDRA', 'CLWT', 'EVGN', 'EVOL', 'EXFO', 'FATE', 'FLKS', 'FPAY', 'FRSX', 'FBIO', 'FWP', 'FRED', 'FLGT', 'FORK', 'FLL', 'FSNN', 'GNMK', 'SELF', 'GLUU', 'GEC', 'HLIT', 'HBIO', 'HPJ', 'HIHO', 'ICAD', 'INVE', 'ISNS', 'IMDZ', 'III', 'INO', 'SNAK', 'IZEA', 'KMDA', 'KBSF', 'KCAP', 'KMPH', 'KERX', 'KONE', 'KOPN', 'LGCYO
# ...

# %%
code_all = list(set(code_01 + code_02))
code_all
# Out:
# ['SPOK',
#  'ESDI',
#  'RDI',
#  'YGYI',
#  'LIFE',
#  'FSNN',
#  'MIND',
#  'NDLS',
#  'AMOT',
#  'AMSWA',
#  'INO',
#  'JVA',
#  'VKTX',
#  'MGIC',
#  'TNAV',
#  'EVOL',
#  'CODX',
#  'AVHI',
#  'LEDS',
#  'BSQR',
#  'RCM',
#  'PSC',
#  'MPAC',
#  'PERY',
#  'RBPAA',
#  'TYME',
#  'CDZI',
#  'ADXS',
#  'ABAC',
#  'ACET',
#  'BBOX',
#  'YTEN',
#  'RADA',
#  'CATC',
#  'ABUS',
#  'CPSS',
#  'TCRD',
#  'OCSL',
#  'CTRN',
#  'KOPN',
#  'CYAN',
#  'MFIN',
#  'FOGO',
#  'POPE',
#  'AAME',
#  'JCS',
#  'FBMS',
#  'EVGN',
#  'MCBC',
#  'XBIT',
#  'TLGT',
#  'FRED',
#  'AWRE',
#  'DRYS',
#  'ICAD',
#  'PESI',
#  'FNLC',
#  'ACHN',
#  'TWIN',
#  'HBCP',
#  'NVLN',
#  'NH',
#  'GLDD',
#  'ADMP',
#  'GAIN',
#  'GLUU',
#  'III',
#  'SHLD',
#  'CCCR',
#  'BBGI',
#  'BOMN',
#  'CALA',
#  'CAAS',
#  'SNOA',
#  'CREG',
#  'LQDT',
#  'MYND',
#  'NLNK',
#  'AVEO',
#  'LMNR',
#  'BSF',
#  'APVO',
#  'PCSB',
#  'APEN',
#  'ATAX',
#  'CADC',
#  'OBCI',
#  'HCM',
#  'DJCO',
#  'MAGS',
#  'RDHL',
# ...

# %%
with open('symbols03.txt', 'w') as f:
    for symbol in code_all:
        f.write(symbol.strip().upper() + '\n')

# %%
f = open('symbols03.txt')
symbols_03 = f.read()
symbols_03 = symbols_03.split()
print(symbols_03)
f.close()
# Out:
# ['SPOK', 'ESDI', 'RDI', 'YGYI', 'LIFE', 'FSNN', 'MIND', 'NDLS', 'AMOT', 'AMSWA', 'INO', 'JVA', 'VKTX', 'MGIC', 'TNAV', 'EVOL', 'CODX', 'AVHI', 'LEDS', 'BSQR', 'RCM', 'PSC', 'MPAC', 'PERY', 'RBPAA', 'TYME', 'CDZI', 'ADXS', 'ABAC', 'ACET', 'BBOX', 'YTEN', 'RADA', 'CATC', 'ABUS', 'CPSS', 'TCRD', 'OCSL', 'CTRN', 'KOPN', 'CYAN', 'MFIN', 'FOGO', 'POPE', 'AAME', 'JCS', 'FBMS', 'EVGN', 'MCBC', 'XBIT', 'TLGT', 'FRED', 'AWRE', 'DRYS', 'ICAD', 'PESI', 'FNLC', 'ACHN', 'TWIN', 'HBCP', 'NVLN', 'NH', 'GLDD', 'ADMP', 'GAIN', 'GLUU', 'III', 'SHLD', 'CCCR', 'BBGI', 'BOMN', 'CALA', 'CAAS', 'SNOA', 'CREG', 'LQDT', 'MYND', 'NLNK', 'AVEO', 'LMNR', 'BSF', 'APVO', 'PCSB', 'APEN', 'ATAX', 'CADC', 'OBCI', 'HCM', 'DJCO', 'MAGS', 'RDHL', 'OMEX', 'GEC', 'ELSE', 'TTPH', 'PFM', 'AKTX', 'QABA', 'BIOS', 'CVGI', 'SGBX', 'GASS', 'SNAK', 'FLKS', 'VVPR', 'NVEC', 'STML', 'ASTC', 'COGT', 'RLJE', 'DTEA', 'XGTIW', 'CTIB', 'OSBC', 'ZIOP', 'LGCYP', 'SALM', 'VTHR', 'BVSN', 'HLIT', 'IPDN', 'HCOM', 'SCKT', 'FLXS', 'LLNW', 'DHXM'
# ...

# %% [markdown]
# # Q3. 下載台灣上市公司基本資料。

# %%
import requests
import pandas as pd
import io

# %%
url = 'http://dts.twse.com.tw/opendata/t187ap03_L.csv'
r = requests.get(url)
r.encoding = 'big5'

# %%
df = pd.read_csv(io.StringIO(r.text), skiprows = 1)
df.head()
# Out:
#             公司代號  公司名稱                     產業別          住址 營利事業統一編號  董事長  總經理  \
# 1101  台灣水泥股份有限公司  水泥工業           台北市中山北路2段113號  11913502.0      張安平  李鐘培  黃健強
# 1102  亞洲水泥股份有限公司  水泥工業  台北市大安區敦化南路2段207號30、31樓   3244509.0      徐旭東  李坤炎  周維崑
# 1103  嘉新水泥股份有限公司  水泥工業            台北市中山北路2段96號  11892801.0      張剛綸  祁士鉅  王立心
# 1104  環球水泥股份有限公司  水泥工業        台北市南京東路二段125號10樓   7568009.0      侯博義  侯博義  楊宗仁
# 1108  幸福水泥股份有限公司  水泥工業           台北市松江路237號15樓  40601248.0      陳兩傳  陳兩傳  溫秀菊
#
#          發言人 發言人職稱          代理發言人 ...  特別股         編制財務報表類型         股票過戶機構  \
# 1101  資深副總經理   蔡立文  (02)2531-7099 ...  1.0      中國信託商業銀行代理部       66365566
# 1102    副總經理   吳玲綾   02-2733-8000 ...  1.0       亞東證券股份有限公司   02-2361-8608
# 1103  執行副總經理   余曉芸  (02)2551-5211 ...  1.0  群益金鼎證券股份有限公司股代部  (02)2702-3999
# 1104      經理   詹志鴻    02-25077801 ...  1.0  凱基證券股份有限公司股務代理部    02-23892999
# 1108   財務部經理   陳一誠       25092188 ...  1.0        永豐金證券股務代理      2381-6288
#
#                     過戶電話          過戶地址  \
# ...

# %% [markdown]
# # Q4. 畫出技術曲線。

# %%
# 建立股價資料的dataframe
import pandas_datareader.data as web
from datetime import datetime

df = web.DataReader('AAPL', 'yahoo', datetime(2017, 1, 1), datetime(2017, 7, 4))
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-01-03  115.800003  116.330002  114.760002  116.150002  114.311760
# 2017-01-04  115.849998  116.510002  115.750000  116.019997  114.183815
# 2017-01-05  115.919998  116.860001  115.809998  116.610001  114.764473
# 2017-01-06  116.779999  118.160004  116.470001  117.910004  116.043915
# 2017-01-09  117.949997  119.430000  117.940002  118.989998  117.106812
# 2017-01-10  118.769997  119.379997  118.300003  119.110001  117.224907
# 2017-01-11  118.739998  119.930000  118.599998  119.750000  117.854782
# 2017-01-12  118.900002  119.300003  118.209999  119.250000  117.362694
# 2017-01-13  119.110001  119.620003  118.809998  119.040001  117.156021
# 2017-01-17  118.339996  120.239998  118.220001  120.000000  118.100822
# 2017-01-18  120.000000  120.500000  119.709999  119.989998  118.090981
# 2017-01-19  119.400002  120.089996  119.370003  119.779999  117.884300
# ...

# %%
# 計算20日ma及標準差
df['20 ma'] = pd.Series.rolling(df['Close'], window = 20).mean()
df['20 sd'] = pd.Series.rolling(df['Close'], window = 20).std()

# %%
# 算出上界及下界
df['Upper Band'] = df['20 ma'] + (df['20 sd']*2)
df['Lower Band'] = df['20 ma'] - (df['20 sd']*2)

# %%
# 畫圖
import matplotlib.pyplot as plt
# %matplotlib inline
df[['Close', '20 ma', 'Upper Band', 'Lower Band']].plot(legend = 'best', figsize=(10, 8))

# %% [markdown]
# # Q5. 策略回測
